# %% [markdown]
# # <center> CONTROLE CONTINU </center>
# ## <center>  VISUALISATION ET COMMUNICATION DES DONNEES </center>
# ### <center>  25/05/2023 </center>
#
# ### Nom:
# ### Prenom:

# %% [markdown]
# Utilisez le fichier "data_ventes.csv" pour répondre aux questions ci-après.
#
# Lisez ce fichier en utilisant Pandas ou NumPy ou en utilisant les fonctions de la bibliothèque matplotlib.

# %% [markdown]
# ### Question 1 :  Lisez le bénéfice total de tous les mois et affichez-le à l'aide d'un tracé linéaire
#
#
# Le tracé de ligne généré doit inclure les propriétés suivantes : –
#
# étiquette de l'axe des X  = numéro du mois
# étiquette de l'axe des Y  = bénéfice total
#
# Le graphique linéaire devrait ressembler à ceci:

# %%
# NOM. Prenom


# NOM. Prenom

# %% [markdown]
# ### Question 2 : Obtenez le bénéfice total de tous les mois et affichez le tracé linéaire avec les propriétés de style suivantes
#
# Le tracé de ligne généré doit respecter les propriétés de style suivantes :
#
# Le style de ligne en pointillés et la couleur de ligne en rouge
# Afficher la légende en bas à droite.
# l'étiquette de l'axe des X = numéro du mois
# l'étiquette de l'axe des Y = nombre d'unités vendues
# Ajouter un marqueur sous forme de cercle d'intérieur noir
# La largeur de ligne doit être de 3
# Le graphique linéaire devrait ressembler à ceci:

# %% [markdown]
# ### Question 3 : Lire toutes les données de vente de produits et les afficher à l'aide d'un graphique multiligne
#
# Affichez le nombre d'unités vendues par mois pour chaque produit à l'aide de tracés multilignes. (c'est-à-dire une ligne de tracé séparée pour chaque produit).
#
# Le graphique devrait ressembler à ceci:

# %% [markdown]
# ### Question 4 : Lisez les données de ventes de dentifrices de chaque mois et affichez-les à l'aide d'un nuage de points
#
# Ajoutez également une grille dans le tracé. le style de quadrillage doit être "--".
#
# Le nuage de points devrait ressembler à ceci:

# %% [markdown]
# ### Question 5 : Lire les données de ventes des crèmes et des savons pour le visage et les afficher à l'aide du graphique à barres
#
# Le graphique à barres doit afficher le nombre d'unités vendues par mois pour chaque produit. Mettez une barre distincte pour chaque produit dans le même graphique.
#
# Le graphique à barres devrait ressembler à ceci:

# %% [markdown]
# ### Question 6 : Lisez les données de ventes de gels de douche de tous les mois et affichez-les à l'aide d'un graphique à barres. Enregistrez ce tracé sur votre disque dur
# Le graphique à barres devrait ressembler à ceci.

# %% [markdown]
# ### Question 7 : Lisez le bénéfice total de chaque mois et affichez-le à l'aide d'un histogramme
#
# L'histogramme devrait ressembler à ceci.

# %% [markdown]
# ### Exercice 8 : Calculez les données de vente totales de l'année dernière pour chaque produit et affichez-les à l'aide d'un graphique à secteurs
#
# Remarque : Dans l'affichage du graphique à secteurs, le nombre d'unités vendues par an pour chaque produit en pourcentage.
#
# Le graphique à secteurs devrait ressembler à ceci.

# %% [markdown]
# ### Exercice 9 : Lisez le nombre de gels de douches et de savons de visage de tous les mois et affichez-les comme la figure:

# %% [markdown]
# ### Question 10 : Lisez toutes les données de vente de produits et affichez-les à l'aide du diagramme empilé (stack plot)
#
# Le diagramme empilé devrait ressembler à ceci.
